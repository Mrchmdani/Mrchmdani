# %% [markdown]
# # **Section 53: Appendix Deep Learning - TensorFlow 1: Introduction**

# %% [markdown]
# ## 370. READ ME!!!!
# ## 1min
# ## Play
# ## 371. How to Install TensorFlow 1
# ## 2min
# ## Start
# ## 372. A Note on Installing Packages in Anaconda
# ## 1min
# ## Play
# ## 373. TensorFlow Intro
# ## 4min
# ## Play
# ## 374. Actual Introduction to TensorFlow
# ## 2min
# ## Play
# ## 375. Types of File Formats, supporting Tensors
# ## 3min
# ## Play
# ## 376. Basic NN Example with TF: Inputs, Outputs, Targets, Weights, Biases
# ## 6min
# ## Play
# ## 377. Basic NN Example with TF: Loss Function and Gradient Descent
# ## 4min
# ## Play
# ## 378. Basic NN Example with TF: Model Output
# ## 6min
# ## Start
# ## 379. Basic NN Example with TF Exercises

# %% [markdown]
# # **Section 54: Appendix Deep Learning - TensorFlow 1: Classifying on the MNIST Dataset**

# %% [markdown]
# ## 380. MNIST: What is the MNIST Dataset?
# ## 2min
# ## Play
# ## 381. MNIST: How to Tackle the MNIST
# ## 3min
# ## Play
# ## 382. MNIST: Relevant Packages
# ## 2min
# ## Play
# ## 383. MNIST: Model Outline
# ## 7min
# ## Play
# ## 384. MNIST: Loss and Optimization Algorithm
# ## 3min
# ## Play
# ## 385. Calculating the Accuracy of the Model
# ## 4min
# ## Play
# ## 386. MNIST: Batching and Early Stopping
# ## 2min
# ## Play
# ## 387. MNIST: Learning
# ## 8min
# ## Play
# ## 388. MNIST: Results and Testing
# ## 6min
# ## Start
# ## 389. MNIST: Exercises
# ## 1min
# ## Start
# ## 390. MNIST: Solutions

# %% [markdown]
# # **Section 55: Appendix Deep Learning - TensorFlow 1: Business Case**

# %% [markdown]
# ## 391. Business Case: Getting Acquainted with the Dataset
# ## 8min
# ## Play
# ## 392. Business Case: Outlining the Solution
# ## 2min
# ## Play
# ## 393. The Importance of Working with a Balanced Dataset
# ## 4min
# ## Play
# ## 394. Business Case: Preprocessing
# ## 12min
# ## Start
# ## 395. Business Case: Preprocessing Exercise
# ## 1min
# ## Play
# ## 396. Creating a Data Provider
# ## 7min
# ## Play
# ## 397. Business Case: Model Outline
# ## 6min
# ## Play
# ## 398. Business Case: Optimization
# ## 5min
# ## Play
# ## 399. Business Case: Interpretation
# ## 2min
# ## Play
# ## 400. Business Case: Testing the Model
# ## 2min
# ## Play
# ## 401. Business Case: A Comment on the Homework
# ## 4min
# ## Start
# ## 402. Business Case: Final Exercise

# %% [markdown]
# # **Section 62: Appendix Additional Python Tools**

# %% [markdown]
# ## 470. Using the .format() Method
# ## 9min
# ## Play
# ## 471. Iterating Over Range Objects
# ## 4min
# ## Play
# ## 472. Introduction to Nested For Loops
# ## 6min
# ## Play
# ## 473. Triple Nested For Loops
# ## 6min
# ## Play
# ## 474. List Comprehensions
# ## 9min
# ## Play
# ## 475. Anonymous (Lambda) Functions

# %% [markdown]
# # **Section 63: Appendix Pandas Fundamentals**

# %% [markdown]
# ## 476. Introduction to pandas Series
# ## 9min
# ## Play
# ## 477. Working with Methods in Python - Part I
# ## 5min
# ## Play
# ## 478. Working with Methods in Python - Part II
# ## 3min
# ## Play
# ## 479. Parameters and Arguments in pandas
# ## 4min
# ## Play
# ## 480. Using .unique() and .nunique()
# ## 4min
# ## Play
# ## 481. Using .sort_values()
# ## 4min
# ## Play
# ## 482. Introduction to pandas DataFrames - Part I
# ## 5min
# ## Play
# ## 483. Introduction to pandas DataFrames - Part II
# ## 5min
# ## Play
# ## 484. pandas DataFrames - Common Attributes
# ## 4min
# ## Play
# ## 485. Data Selection in pandas DataFrames
# ## 7min
# ## Play
# ## 486. pandas DataFrames - Indexing with .iloc[]
# ## 6min
# ## Play
# ## 487. pandas DataFrames - Indexing with .loc[]

# %% [markdown]
# # **Section 64: Appendix Working with Text Files in Python**

# %% [markdown]
# ## 488. An Introduction to Working with Files in Python
# ## 4min
# ## Play
# ## 489. File vs File Object, Reading vs Parsing Data
# ## 3min
# ## Play
# ## 490. Structured, Semi-Structured and Unstructured Data
# ## 3min
# ## Play
# ## 491. Text Files and Data Connectivity
# ## 3min
# ## Play
# ## 492. Importing Data in Python - Principles
# ## 5min
# ## Play
# ## 493. Plain Text Files, Flat Files and More
# ## 5min
# ## Play
# ## 494. Text Files of Fixed Width
# ## 1min
# ## Play
# ## 495. Common Naming Conventions
# ## 4min
# ## Play
# ## 496. Importing Text Files - open()
# ## 9min
# ## Play
# ## 497. Importing Text Files - with open()
# ## 5min
# ## Play
# ## 498. Importing *.csv Files - Part I
# ## 6min
# ## Play
# ## 499. Importing *.csv Files - Part II
# ## 3min
# ## Play
# ## 500. Importing *.csv Files - Part III
# ## 6min
# ## Play
# ## 501. Importing Data with index_col
# ## 3min
# ## Play
# ## 502. Importing Data with .loadtxt() and .genfromtxt()
# ## 11min
# ## Play
# ## 503. Importing Data - Partial Cleaning While Importing Data
# ## 7min
# ## Start
# ## 504. Importing Data with NumPy - Exercise
# ## 1min
# ## Play
# ## 505. Importing Data from *.json Files
# ## 5min
# ## Play
# ## 506. An Introduction to Working with Excel Files in Python
# ## 4min
# ## Play
# ## 507. Working with Excel (*.xlsx) Data
# ## 2min
# ## Play
# ## 508. Importing Data in Python - an Important Exercise
# ## 6min
# ## Play
# ## 509. Importing Data with the .squeeze() Method
# ## 3min
# ## Play
# ## 510. Importing Files in Jupyter
# ## 3min
# ## Play
# ## 511. Saving Your Data with pandas
# ## 3min
# ## Play
# ## 512. Saving Your Data with NumPy - Part I - *.npy
# ## 5min
# ## Play
# ## 513. Saving Your Data with NumPy - Part II - *.npz
# ## 5min
# ## Play
# ## 514. Saving Your Data with NumPy - Part III - *.csv
# ## 4min
# ## Start
# ## 515. Saving Data with Numpy - Exercise
# ## 1min
# ## Play
# ## 516. Working with Text Files in Python - Conclusion
